# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/rq1_features.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  temperature_2m  wind_speed_10m  wind_direction_10m  \
# 0         168            17.7             7.7                  79
# 1         169            17.1             8.0                  72
# 2         170            16.6             6.9                  81
# 3         171            14.8             5.4                  70
# 4         172            14.4             4.5                  76
#
#    cloud_cover  shortwave_radiation  precipitation  Price (EUR/MWhe)       P  \
# 0            0                  0.0            0.0             86.04    0.00
# 1           57                  0.0            0.0             82.23    0.00
# 2            9                  0.0            0.0             83.92    0.00
# 3            0                  0.0            0.0             83.71    1.83
# 4          100                 12.0            0.0             84.95  105.68
#
#    Gb(i)  ...       Datetime (UTC)  hour  day_of_week  month  is_weekend  \
# ...

# %%
df_day = df[df['H_sun'] > 0].copy()

# %%
print(f"NaN колони во P_lag_24h: {df_day['P_lag_24h'].isna().sum()}")
# Out:
# NaN колони во P_lag_24h: 0

# %%
df_day.to_csv('../data/processed/rq2_features_daylight.csv')
